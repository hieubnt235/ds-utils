# %%
# %load_ext autoreload
# %aimport ds_utils.huggan_smithsonian_butterflies_subset
# %autoreload 1

from ds_utils.huggan_smithsonian_butterflies_subset import Dataset
dataset = Dataset()
print(dataset)
dataset[:5]["images"].shape
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Dataset({
#     features: ['image_url', 'image_alt', 'id', 'name', 'scientific_name', 'gender', 'taxonomy', 'region', 'locality', 'date', 'usnm_no', 'guid', 'edan_url', 'source', 'stage', 'image', 'image_hash', 'sim_score'],
#     num_rows: 1000
# })
# torch.Size([5, 3, 128, 128])

# %%
dataset.show_images(range(5))

# %%
dataset.show_images(range(5),raw=False)

# %%
dataset.show(dataset[7:10]["raw_images"])

# %%
dataset[23]["raw_images"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x430>
